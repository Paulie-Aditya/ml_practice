# %% [markdown]
# <a href="https://colab.research.google.com/github/Paulie-Aditya/ml_practice/blob/main/kaggle_grind.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import requests

# %%
api_key = "ea9619c25a8b11f45b407b68b3f95379"
page_no = 1
#url = f'https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=en-US&page={page_no}'

url = f'https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={page_no}'

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYTk2MTljMjVhOGIxMWY0NWI0MDdiNjhiM2Y5NTM3OSIsInN1YiI6IjY0ZTkwZjNiYzYxM2NlMDBjOWYxZTg5NiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.MYC9gwCgb20W6JMAvlCUfrxcssbpukISvRt33tJtxVA"
}

response = requests.get(url, headers=headers)
print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/tmU7GeKVybMWFButWEGl2M4GeiP.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.","popularity":123.773,"poster_path":"/3bhkrj58Vtu7enYsRolD1fZdja1.jpg","release_date":"1972-03-14","title":"The Godfather","video":false,"vote_average":8.7,"vote_count":18479},{"adult":false,"backdrop_path":"/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     123.773
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     132.698
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      91.909
# 3  The true story of how businessman Oskar Schind...   1993-12-15      61.483
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      52.514
#
#    vote_average  vote_count
# 0           8.7       18479
# 1           8.7       24413
# 2           8.6       11167
# 3           8.6       14439
# 4           8.6        4228

# %%
temp_df.shape
# Out:
# (20, 7)

# %%
df = pd.DataFrame()

# %%
for i in range(1,100):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=en-US&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat((df,temp_df),ignore_index=True)

# %%
df
# Out:
#           id                            title  \
# 0        238                    The Godfather
# 1        278         The Shawshank Redemption
# 2        240            The Godfather Part II
# 3        424                 Schindler's List
# 4      19404      Dilwale Dulhania Le Jayenge
# ...      ...                              ...
# 16455  13004    Barbie and the Diamond Castle
# 16456   9065                           Europa
# 16457   7863                            Shine
# 16458  65754  The Girl with the Dragon Tattoo
# 16459  57361                   The Yellow Sea
#
#                                                 overview release_date  \
# 0      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1      Framed in the 1940s for the double murder of h...   1994-09-23
# 2      In the continuing saga of the Corleone crime f...   1974-12-20
# 3      The true story of how businessman Oskar Schind...   1993-12-15
# ...

# %%
df.shape
# Out:
# (16460, 7)

# %%
df.to_csv('movies.csv')
